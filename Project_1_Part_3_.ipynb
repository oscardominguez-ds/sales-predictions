# %% [markdown]
# <a href="https://colab.research.google.com/github/oscardominguez-ds/sales-predictions/blob/main/Project_1_Part_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 1 - Part 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

import seaborn as sns
import numpy as np

filename = '/content/sales_predictions'
df = pd.read_csv(filename)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Our histograms tells us that there are more units sold around the 2,000 rupees price than any other price. 

df['Item_Outlet_Sales'].hist(bins = 'auto');
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')

# %%
#I used the same column from above to see the same data in a different way
#This boxplot tells us the outliers. Outliers are the stores that generated more sales than the average.
#Item_Outlet_Sales boxplot tells give us the average money in sales is 2,000 rupees.


fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (8,5))
boxplots = axes.boxplot([df['Item_Outlet_Sales']],
           notch = True,
           labels=['Item_Outlet_Sales'],
           widths = .7,
           patch_artist=True,
           medianprops = dict(linestyle='-', linewidth=2, color='Yellow'),
           boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4)
          );

# %%
#This boxplot tells us that the median retail price is 150 for items sold with no outliers.

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (8,5))
boxplots = axes.boxplot([df['Item_MRP']],
           notch = True,
           labels=['Item_MRP'],
           widths = .7,
           patch_artist=True,
           medianprops = dict(linestyle='-', linewidth=2, color='Yellow'),
           boxprops = dict(linestyle='--', linewidth=2, color='Black', facecolor = 'blue', alpha = .4)
          );

# %%
#Heatmap shows that there is a moderate correlation between Item_Outlet_Sales and Item_MRP
corr = df.corr()
sns.heatmap(corr, cmap = 'Greens', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Project 1 - Part 4

# %% [markdown]
# #Chart 1
# ###Does outlet size affect the number of sales?
# (answer in the code comments)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#Build on your previous cleaning, exploration, and analysis.
#Create a minimum of two data visualizations that help others understand trends in 
#the data (explanatory data analysis).
#Since these graphs are for reporting purposes, make sure they 
#look nice by including titles, legends, etc.

#Yes, our graph does show that there are slightly more sales with higher outlet sizes

fig, axes = plt.subplots(ncols=1, figsize=(7,4))
sns.barplot(data = df, x = "Outlet_Size" , y = 'Item_Outlet_Sales');
axes.set_title('Outlet size vs. Sales', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Outlet size vs. Sales')

# %% [markdown]
# ###Does outlet size affect item visibility?
#
# (answer in the code comments)

# %%
#not so much, both medium and small outlet sizes had more item visibility than 
#the high outlet size stores.

plt.bar(df["Outlet_Size"],df['Item_Visibility'], color='teal');

plt.xlabel("Outlet Size vs Item Visibility")
plt.ylabel('Outlet Size')
plt.title('Item Visibility Percentage')
plt.show()

# %% [markdown]
# #Does item visibility affect item sales?

# %%
#no, items with lesses visibility had more sales.

plt.scatter(df['Item_Visibility'] , df['Item_Outlet_Sales'], color='blue', edgecolors='black')
plt.title("Item Visivility vs. Item Sales")
plt.xlabel("Item Visibility")
plt.ylabel("Item Outlet Sales")
plt.show()
